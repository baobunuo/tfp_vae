# %%
from VAE.vae import VAE
from VAE.datasets import get_dataset

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
# %matplotlib inline
# %config InlineBackend.figure_formats = ['svg']

# %%
## hyperparams

hps = tf.contrib.training.HParams(
    batch_size=64,
    img_height=32,
    img_width=32,
    img_channels=1,
    z_dim=16,
    discrete_outputs=True)

vae = VAE(hps)
init_op = tf.global_variables_initializer()

tf.logging.set_verbosity(tf.logging.ERROR)
sess = tf.Session()
_ = sess.run(init_op)

# %%
dataset = get_dataset(
    'MNIST', hps.batch_size, hps.img_height, hps.img_width)

# %%
ref = dataset.get_reference_batch()

# %%
def visualize_batch(batch):
    if hps.img_channels == 1:
        batch = batch[:, :, :, 0]
    viz = np.concatenate([batch[i] for i in range(0, hps.batch_size, hps.batch_size // 6)], axis=1)
    cmap_spec = 'gray' if hps.img_channels == 1 else None
    plt.imshow(viz, cmap=cmap_spec)
    plt.show()

# %%
num_epochs = 3
for e in range(0, num_epochs):
    for i in range(0, mnist_dataset.train_dataset_size // hps.batch_size):
        clear_output(wait=True)
    
        x = mnist_dataset.get_batch()
        elbo = vae.train(sess, x)
        print('Epoch {}, Iter {}... ELBO: {}'.format(e, i, elbo))
        recon_x = vae.reconstruct(sess, x)
        visualize_batch(recon_x)
        
    mnist_dataset.new_epoch()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-ff497376d282> in <module>()
#       8
#       9         x = mnist_dataset.get_batch()
# ---> 10         elbo = vae.train(sess, x)
#      11         print('Epoch {}, Iter {}... ELBO: {}'.format(e, i, elbo))
#      12         recon_x = vae.reconstruct(sess, x)
#
# ~/git/tfp_vae/VAE/vae.py in train(self, sess, x)
#      46
#      47     def train(self, sess, x):
# ---> 48         _, elbo = sess.run([self.train_op, self.elbo], feed_dict={self.input_x: x})
#      49         return elbo
#      50
#
# ~/anaconda3/envs/tf18/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tf18/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/anaconda3/envs/tf18/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/tf18/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/tf18/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/tf18/lib/python3.5/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
def interpolate_random_pairs(x, num_pairs=5):
    rows = []
    def interpolate_pair():
        i = np.random.randint(hps.batch_size)
        j = np.random.randint(hps.batch_size)
        x1 = x[i]
        x2 = x[j]
        interpolations = vae.interpolate(sess, x1, x2)
        
        row = np.concatenate([x1] + [interpolations[i] for i in range(0, 5)] + [x2], axis=1)
        if hps.img_channels == 1:
            row = row[:,:,0]
            
        return row
    
    rows = [interpolate_pair() for _ in range(0, num_pairs)]
    viz = np.concatenate(rows, axis=0)
    cmap_spec = 'gray' if hps.img_channels == 1 else None
    plt.imshow(viz, cmap=cmap_spec)
    plt.show()

# %%
x = mnist_dataset.get_reference_batch()
interpolate_random_pairs(x)

# %%
x = mnist_dataset.get_reference_batch()
interpolate_random_pairs(x)
